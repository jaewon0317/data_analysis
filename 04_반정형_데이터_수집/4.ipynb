# %%
data = {'단과대학':'공학대학','학과':'ai소프트웨어과','전화번호':'0308'}
print(data)
print(data.keys())
print(data.values())
print(data.items())
print(data['단과대학'])
print(type(data))
# Out:
# {'단과대학': '공학대학', '학과': 'ai소프트웨어과', '전화번호': '0308'}
# dict_keys(['단과대학', '학과', '전화번호'])
# dict_values(['공학대학', 'ai소프트웨어과', '0308'])
# dict_items([('단과대학', '공학대학'), ('학과', 'ai소프트웨어과'), ('전화번호', '0308')])
# 공학대학
# <class 'dict'>

# %%
import json
jdata = json.dumps(data, ensure_ascii=False)
print(jdata)
print(type(jdata))
# Out:
# {"단과대학": "공학대학", "학과": "ai소프트웨어과", "전화번호": "0308"}
# <class 'str'>

# %%
data2 = json.loads(jdata)
print(data2)
print(type(data2))
# Out:
# {'단과대학': '공학대학', '학과': 'ai소프트웨어과', '전화번호': '0308'}
# <class 'dict'>

# %%
major = [{'단과대학': '공학대학', '학과': 'ai소프트웨어과', '전화번호': '0308'},
         {'단과대학': '공학대학', '학과': '소프트웨어과', '전화번호': '0307'},
         {'단과대학': '공학대학', '학과': '보안과', '전화번호': '0306'}]
print(major)
print(type(major))
# Out:
# [{'단과대학': '공학대학', '학과': 'ai소프트웨어과', '전화번호': '0308'}, {'단과대학': '공학대학', '학과': '소프트웨어과', '전화번호': '0307'}, {'단과대학': '공학대학', '학과': '보안과', '전화번호': '0306'}]
# <class 'list'>

# %%
jdata2 = json.dumps(major, ensure_ascii=False)
print(jdata2)
print(type(jdata2))
# Out:
# [{"단과대학": "공학대학", "학과": "ai소프트웨어과", "전화번호": "0308"}, {"단과대학": "공학대학", "학과": "소프트웨어과", "전화번호": "0307"}, {"단과대학": "공학대학", "학과": "보안과", "전화번호": "0306"}]
# <class 'str'>

# %%
data3 = json.loads(jdata2)
print(data3)
print(type(data3))
# Out:
# [{'단과대학': '공학대학', '학과': 'ai소프트웨어과', '전화번호': '0308'}, {'단과대학': '공학대학', '학과': '소프트웨어과', '전화번호': '0307'}, {'단과대학': '공학대학', '학과': '보안과', '전화번호': '0306'}]
# <class 'list'>

# %%
import pandas as pd
data = pd.DataFrame(data2)
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 data = pd.DataFrame(data2)
#       3 data
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
with open('대학정보.json', 'w') as fp:
    json.dump(major, fp)

# %%
import json
with open('4주차 실습파일/전국휴양림표준데이터.json','r')as files:
    temp = json.load(files)
temp
# Out:
# {'fields': [{'id': '휴양림명'},
#   {'id': '시도명'},
#   {'id': '휴양림구분'},
#   {'id': '휴양림면적'},
#   {'id': '수용인원수'},
#   {'id': '입장료'},
#   {'id': '숙박가능여부'},
#   {'id': '주요시설명'},
#   {'id': '소재지도로명주소'},
#   {'id': '관리기관명'},
#   {'id': '휴양림전화번호'},
#   {'id': '홈페이지주소'},
#   {'id': '위도'},
#   {'id': '경도'},
#   {'id': '데이터기준일자'},
#   {'id': '제공기관코드'},
#   {'id': '제공기관명'}],
#  'records': [{'휴양림명': '광치자연휴양림',
#    '시도명': '강원도',
#    '휴양림구분': '공유림',
#    '휴양림면적': '51',
#    '수용인원수': '160',
#    '입장료': '3000원',
#    '숙박가능여부': 'Y',
#    '주요시설명': '숲속의집, 휴양관, 숲속카페,무장애나눔길',
#    '소재지도로명주소': '강원도 양구군 남면 광치령로 1794번길 265',
#    '관리기관명': '강원도 양구군청',
#    '휴양림전화번호': '033-482-3115',
#    '홈페이지주소': 'http://www.foresttrip.go.kr',
#    '위도': '38.14199686',
#    '경도': '128.0710755',
#    '데이터기준일자': '2022-08-31',
#    '제공기관코드': '4320000',
#    '제공기관명': '강원도 양구군'},
#   {'휴양림명': '삼척활기자연휴양림',
#    '시도명': '강원도',
#    '휴양림구분': '사유림',
#    '휴양림면적': '75625',
#    '수용인원수': '175',
#    '입장료': '0',
#    '숙박가능여부': 'Y',
# ...

# %%
temp['records'][0]
# Out:
# {'휴양림명': '광치자연휴양림',
#  '시도명': '강원도',
#  '휴양림구분': '공유림',
#  '휴양림면적': '51',
#  '수용인원수': '160',
#  '입장료': '3000원',
#  '숙박가능여부': 'Y',
#  '주요시설명': '숲속의집, 휴양관, 숲속카페,무장애나눔길',
#  '소재지도로명주소': '강원도 양구군 남면 광치령로 1794번길 265',
#  '관리기관명': '강원도 양구군청',
#  '휴양림전화번호': '033-482-3115',
#  '홈페이지주소': 'http://www.foresttrip.go.kr',
#  '위도': '38.14199686',
#  '경도': '128.0710755',
#  '데이터기준일자': '2022-08-31',
#  '제공기관코드': '4320000',
#  '제공기관명': '강원도 양구군'}

# %%
data = []
for d in temp['records']:
    data.append(d)
print(data)
# Out:
# [{'휴양림명': '광치자연휴양림', '시도명': '강원도', '휴양림구분': '공유림', '휴양림면적': '51', '수용인원수': '160', '입장료': '3000원', '숙박가능여부': 'Y', '주요시설명': '숲속의집, 휴양관, 숲속카페,무장애나눔길', '소재지도로명주소': '강원도 양구군 남면 광치령로 1794번길 265', '관리기관명': '강원도 양구군청', '휴양림전화번호': '033-482-3115', '홈페이지주소': 'http://www.foresttrip.go.kr', '위도': '38.14199686', '경도': '128.0710755', '데이터기준일자': '2022-08-31', '제공기관코드': '4320000', '제공기관명': '강원도 양구군'}, {'휴양림명': '삼척활기자연휴양림', '시도명': '강원도', '휴양림구분': '사유림', '휴양림면적': '75625', '수용인원수': '175', '입장료': '0', '숙박가능여부': 'Y', '주요시설명': '휴양관(송폭헌)+ 한옥(방우재)+ 한옥(세우재)+숲속의집(구희당)+숲속의집(삼락당)', '소재지도로명주소': '강원도 삼척시 미로면 준경길 651-43(지번활기리 403-1)', '관리기관명': '삼척동해태백산림조합', '휴양림전화번호': '033-574-0032', '홈페이지주소': 'https://www.foresttrip.go.kr/indvz/main.do?hmpgId=ID02030104', '위도': '37.38099374', '경도': '129.0601226', '데이터기준일자': '2023-01-04', '제공기관코드': '4240000', '제공기관명': '강원도 삼척시'}, {'휴양림명': '데미샘자연휴양림', '시도명': '전라북도', '휴양림구분': '공유림', '휴양림면적': '200000', '수용인원수': '131', '입장료': '무료', '숙박가능여부': 'Y', '주요시설명': '휴양관+숲속의집+숲문화마당+명상의숲 등', '소재지도
# ...

# %%
pdData = pd.DataFrame(data)
pdData
# Out:
#           휴양림명   시도명 휴양림구분    휴양림면적 수용인원수  \
# 0      광치자연휴양림   강원도   공유림       51   160
# 1    삼척활기자연휴양림   강원도   사유림    75625   175
# 2     데미샘자연휴양림  전라북도   공유림   200000   131
# 3    강릉임해자연휴양림   강원도   공유림  1160000   105
# 4      금강자연휴양림  충청남도   공유림  1840000   226
# ..         ...   ...   ...      ...   ...
# 208   좌구산자연휴양림  충청북도   공유림   730000   251
# 209    횡성자연휴양림   강원도   사유림   498263   300
# 210   주천강자연휴양림   강원도   사유림  2296100   400
# 211        숲체원   강원도   국유림   159710   300
# 212     청태산휴양림   강원도   국유림   159520  1500
#
#                                                    입장료 숙박가능여부  \
# 0                                                3000원      Y
# 1                                                    0      Y
# 2                                                   무료      Y
# 3    비수기 평일[(6인실)70000원+(5인실)65000원+(4인실)50000원]+비수...      Y
# 4                                                 1500      Y
# ..                                                 ...    ...
# ...

# %%
pdData.to_excel('자연휴양림출력화일.xlsx')
