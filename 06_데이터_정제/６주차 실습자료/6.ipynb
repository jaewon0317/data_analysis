# %%
import pandas as pd

df = (pd.read_excel('성적.xlsx'))
df.head()
# Out:
#       ID   성별    출석  프로젝트    실험
# 0  S1233    남   2.0  12.0  25.0
# 1  S1244    남  17.0   2.0  22.0
# 2    NaN  NaN   NaN   NaN   NaN
# 3  S1254    남   2.0  16.0  25.0
# 4  S1256    3   NaN  11.0  25.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      31 non-null     object
#  1   성별      31 non-null     object
#  2   출석      25 non-null     float64
#  3   프로젝트    25 non-null     float64
#  4   실험      27 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 1.4+ KB

# %%
df['출석'].value_counts()
# Out:
# 출석
# 2.0     9
# 19.0    5
# 18.0    3
# 16.0    3
# 17.0    2
# 12.0    1
# 9.0     1
# 15.0    1
# Name: count, dtype: int64

# %%
df['출석'].value_counts(dropna=False)
# Out:
# 출석
# 2.0     9
# NaN     7
# 19.0    5
# 18.0    3
# 16.0    3
# 17.0    2
# 12.0    1
# 9.0     1
# 15.0    1
# Name: count, dtype: int64

# %%
df['프로젝트'].value_counts(dropna=False)
# Out:
# 프로젝트
# NaN     7
# 12.0    4
# 2.0     4
# 16.0    4
# 25.0    4
# 11.0    2
# 17.0    2
# 22.0    1
# 18.0    1
# 23.0    1
# 24.0    1
# 5.0     1
# Name: count, dtype: int64

# %%
df.isna()
# Out:
#        ID     성별     출석   프로젝트     실험
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2    True   True   True   True   True
# 3   False  False  False  False  False
# 4   False  False   True  False  False
# 5   False  False  False  False  False
# 6   False  False  False  False  False
# 7   False  False  False  False   True
# 8   False  False   True  False  False
# 9   False  False  False  False  False
# 10  False  False  False  False  False
# 11  False  False  False   True  False
# 12  False  False  False  False  False
# 13  False  False  False  False  False
# 14  False  False  False   True  False
# 15  False  False  False  False  False
# 16  False  False   True  False  False
# 17  False  False  False  False  False
# 18  False  False  False  False  False
# 19  False  False  False  False  False
# 20  False  False  False  False   True
# 21  False  False  False   True  False
# 22  False  False  False  False   True
# 23  False  False  False  False  False
# ...

# %%
df['프로젝트'].isna()
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29     True
# 30     True
# 31    False
# Name: 프로젝트, dtype: bool

# %%
df[['출석','프로젝트']].isna()
# Out:
#        출석   프로젝트
# 0   False  False
# 1   False  False
# 2    True   True
# 3   False  False
# 4    True  False
# 5   False  False
# 6   False  False
# 7   False  False
# 8    True  False
# 9   False  False
# 10  False  False
# 11  False   True
# 12  False  False
# 13  False  False
# 14  False   True
# 15  False  False
# 16   True  False
# 17  False  False
# 18  False  False
# 19  False  False
# 20  False  False
# 21  False   True
# 22  False  False
# 23  False  False
# 24  False   True
# 25  False  False
# 26   True  False
# 27   True  False
# 28  False  False
# 29   True   True
# 30  False   True
# 31  False  False

# %%
df[['출석','프로젝트']].isna().sum()
# Out:
# 출석      7
# 프로젝트    7
# dtype: int64

# %%
df2 = pd.read_excel('성적2.xlsx')
df2
# Out:
#        ID   성별    출석  프로젝트    실험
# 0   S1233    남   2.0  12.0  25.0
# 1   S1244    남  17.0   2.0  22.0
# 2     NaN  NaN   NaN   NaN   NaN
# 3   S1254    남   2.0  16.0  25.0
# 4   S1256    3   NaN  11.0  25.0
# 5   S1384    남  12.0  22.0  12.0
# 6   S1391    여  18.0  25.0   8.0
# 7   S1393    남   NaN  25.0   NaN
# 8   S1399    남   NaN   2.0  17.0
# 9   S1411    여  19.0  12.0  17.0
# 10  S1411    여  19.0  12.0  17.0
# 11  S1414    여  18.0   NaN  23.0
# 12  S1421    남   9.0  12.0   1.0
# 13  S1424    여  19.0   2.0  15.0
# 14  S1428    남  19.0   NaN   2.0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      14 non-null     object
#  1   성별      14 non-null     object
#  2   출석      11 non-null     float64
#  3   프로젝트    12 non-null     float64
#  4   실험      13 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 732.0+ bytes

# %%
df2.isna()
# Out:
#        ID     성별     출석   프로젝트     실험
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2    True   True   True   True   True
# 3   False  False  False  False  False
# 4   False  False   True  False  False
# 5   False  False  False  False  False
# 6   False  False  False  False  False
# 7   False  False   True  False   True
# 8   False  False   True  False  False
# 9   False  False  False  False  False
# 10  False  False  False  False  False
# 11  False  False  False   True  False
# 12  False  False  False  False  False
# 13  False  False  False  False  False
# 14  False  False  False   True  False

# %%
df2.dropna(subset='출석')
# Out:
#        ID 성별    출석  프로젝트    실험
# 0   S1233  남   2.0  12.0  25.0
# 1   S1244  남  17.0   2.0  22.0
# 3   S1254  남   2.0  16.0  25.0
# 5   S1384  남  12.0  22.0  12.0
# 6   S1391  여  18.0  25.0   8.0
# 9   S1411  여  19.0  12.0  17.0
# 10  S1411  여  19.0  12.0  17.0
# 11  S1414  여  18.0   NaN  23.0
# 12  S1421  남   9.0  12.0   1.0
# 13  S1424  여  19.0   2.0  15.0
# 14  S1428  남  19.0   NaN   2.0

# %%
df2.dropna(subset=['출석','프로젝트'])
# Out:
#        ID 성별    출석  프로젝트    실험
# 0   S1233  남   2.0  12.0  25.0
# 1   S1244  남  17.0   2.0  22.0
# 3   S1254  남   2.0  16.0  25.0
# 5   S1384  남  12.0  22.0  12.0
# 6   S1391  여  18.0  25.0   8.0
# 9   S1411  여  19.0  12.0  17.0
# 10  S1411  여  19.0  12.0  17.0
# 12  S1421  남   9.0  12.0   1.0
# 13  S1424  여  19.0   2.0  15.0

# %%
df2.dropna(axis=0, subset = '출석')
# Out:
#        ID 성별    출석  프로젝트    실험
# 0   S1233  남   2.0  12.0  25.0
# 1   S1244  남  17.0   2.0  22.0
# 3   S1254  남   2.0  16.0  25.0
# 5   S1384  남  12.0  22.0  12.0
# 6   S1391  여  18.0  25.0   8.0
# 9   S1411  여  19.0  12.0  17.0
# 10  S1411  여  19.0  12.0  17.0
# 11  S1414  여  18.0   NaN  23.0
# 12  S1421  남   9.0  12.0   1.0
# 13  S1424  여  19.0   2.0  15.0
# 14  S1428  남  19.0   NaN   2.0

# %%
df2.dropna(axis=0,how='all')
# Out:
#        ID 성별    출석  프로젝트    실험
# 0   S1233  남   2.0  12.0  25.0
# 1   S1244  남  17.0   2.0  22.0
# 3   S1254  남   2.0  16.0  25.0
# 4   S1256  3   NaN  11.0  25.0
# 5   S1384  남  12.0  22.0  12.0
# 6   S1391  여  18.0  25.0   8.0
# 7   S1393  남   NaN  25.0   NaN
# 8   S1399  남   NaN   2.0  17.0
# 9   S1411  여  19.0  12.0  17.0
# 10  S1411  여  19.0  12.0  17.0
# 11  S1414  여  18.0   NaN  23.0
# 12  S1421  남   9.0  12.0   1.0
# 13  S1424  여  19.0   2.0  15.0
# 14  S1428  남  19.0   NaN   2.0

# %%
df2.dropna(axis=0,thresh=5)
# Out:
#        ID 성별    출석  프로젝트    실험
# 0   S1233  남   2.0  12.0  25.0
# 1   S1244  남  17.0   2.0  22.0
# 3   S1254  남   2.0  16.0  25.0
# 5   S1384  남  12.0  22.0  12.0
# 6   S1391  여  18.0  25.0   8.0
# 9   S1411  여  19.0  12.0  17.0
# 10  S1411  여  19.0  12.0  17.0
# 12  S1421  남   9.0  12.0   1.0
# 13  S1424  여  19.0   2.0  15.0

# %%
df3 = pd.read_excel('성적3.xlsx')

# %%
df3
# Out:
#        ID 성별    출석  프로젝트    실험
# 0   S1233  남   2.0  12.0  25.0
# 1   S1244  남  17.0   2.0  22.0
# 2   S1254  남   2.0  16.0  25.0
# 3   S1244  3   NaN  11.0  25.0
# 4   S1384  남  12.0  22.0  12.0
# 5   S1391  여  18.0  25.0   8.0
# 6   S1393  남   2.0  25.0   NaN
# 7   S1399  남   NaN   2.0  17.0
# 8   S1411  여  19.0  12.0  17.0
# 9   S1411  여  19.0  12.0  17.0
# 10  S1414  여  18.0   NaN  23.0
# 11  S1421  3   9.0  12.0   1.0
# 12  S1424  여  19.0   2.0  15.0
# 13  S1428  남  19.0   NaN   2.0
# 14  S1433  남  19.0  16.0   5.0

# %%
df3.interpolate()
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_747/145165934.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df3.interpolate()
#        ID 성별    출석  프로젝트    실험
# 0   S1233  남   2.0  12.0  25.0
# 1   S1244  남  17.0   2.0  22.0
# 2   S1254  남   2.0  16.0  25.0
# 3   S1244  3   7.0  11.0  25.0
# 4   S1384  남  12.0  22.0  12.0
# 5   S1391  여  18.0  25.0   8.0
# 6   S1393  남   2.0  25.0  12.5
# 7   S1399  남  10.5   2.0  17.0
# 8   S1411  여  19.0  12.0  17.0
# 9   S1411  여  19.0  12.0  17.0
# 10  S1414  여  18.0  12.0  23.0
# 11  S1421  3   9.0  12.0   1.0
# 12  S1424  여  19.0   2.0  15.0
# 13  S1428  남  19.0   9.0   2.0
# 14  S1433  남  19.0  16.0   5.0

# %%
df3.fillna(method='ffill')
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_747/787188533.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3.fillna(method='ffill')
#        ID 성별    출석  프로젝트    실험
# 0   S1233  남   2.0  12.0  25.0
# 1   S1244  남  17.0   2.0  22.0
# 2   S1254  남   2.0  16.0  25.0
# 3   S1244  3   2.0  11.0  25.0
# 4   S1384  남  12.0  22.0  12.0
# 5   S1391  여  18.0  25.0   8.0
# 6   S1393  남   2.0  25.0   8.0
# 7   S1399  남   2.0   2.0  17.0
# 8   S1411  여  19.0  12.0  17.0
# 9   S1411  여  19.0  12.0  17.0
# 10  S1414  여  18.0  12.0  23.0
# 11  S1421  3   9.0  12.0   1.0
# 12  S1424  여  19.0   2.0  15.0
# 13  S1428  남  19.0   2.0   2.0
# 14  S1433  남  19.0  16.0   5.0

# %%
df3.fillna(method='bfill')
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_747/1827610249.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3.fillna(method='bfill')
#        ID 성별    출석  프로젝트    실험
# 0   S1233  남   2.0  12.0  25.0
# 1   S1244  남  17.0   2.0  22.0
# 2   S1254  남   2.0  16.0  25.0
# 3   S1244  3  12.0  11.0  25.0
# 4   S1384  남  12.0  22.0  12.0
# 5   S1391  여  18.0  25.0   8.0
# 6   S1393  남   2.0  25.0  17.0
# 7   S1399  남  19.0   2.0  17.0
# 8   S1411  여  19.0  12.0  17.0
# 9   S1411  여  19.0  12.0  17.0
# 10  S1414  여  18.0  12.0  23.0
# 11  S1421  3   9.0  12.0   1.0
# 12  S1424  여  19.0   2.0  15.0
# 13  S1428  남  19.0  16.0   2.0
# 14  S1433  남  19.0  16.0   5.0

# %%
df3.fillna(0)
# Out:
#        ID 성별    출석  프로젝트    실험
# 0   S1233  남   2.0  12.0  25.0
# 1   S1244  남  17.0   2.0  22.0
# 2   S1254  남   2.0  16.0  25.0
# 3   S1244  3   0.0  11.0  25.0
# 4   S1384  남  12.0  22.0  12.0
# 5   S1391  여  18.0  25.0   8.0
# 6   S1393  남   2.0  25.0   0.0
# 7   S1399  남   0.0   2.0  17.0
# 8   S1411  여  19.0  12.0  17.0
# 9   S1411  여  19.0  12.0  17.0
# 10  S1414  여  18.0   0.0  23.0
# 11  S1421  3   9.0  12.0   1.0
# 12  S1424  여  19.0   2.0  15.0
# 13  S1428  남  19.0   0.0   2.0
# 14  S1433  남  19.0  16.0   5.0

# %%
df3.fillna({'출석':10,'프로젝트':20})
# Out:
#        ID 성별    출석  프로젝트    실험
# 0   S1233  남   2.0  12.0  25.0
# 1   S1244  남  17.0   2.0  22.0
# 2   S1254  남   2.0  16.0  25.0
# 3   S1244  3  10.0  11.0  25.0
# 4   S1384  남  12.0  22.0  12.0
# 5   S1391  여  18.0  25.0   8.0
# 6   S1393  남   2.0  25.0   NaN
# 7   S1399  남  10.0   2.0  17.0
# 8   S1411  여  19.0  12.0  17.0
# 9   S1411  여  19.0  12.0  17.0
# 10  S1414  여  18.0  20.0  23.0
# 11  S1421  3   9.0  12.0   1.0
# 12  S1424  여  19.0   2.0  15.0
# 13  S1428  남  19.0  20.0   2.0
# 14  S1433  남  19.0  16.0   5.0

# %%
df3.fillna(df3['출석'].mean())
# Out:
#        ID 성별         출석       프로젝트         실험
# 0   S1233  남   2.000000  12.000000  25.000000
# 1   S1244  남  17.000000   2.000000  22.000000
# 2   S1254  남   2.000000  16.000000  25.000000
# 3   S1244  3  13.461538  11.000000  25.000000
# 4   S1384  남  12.000000  22.000000  12.000000
# 5   S1391  여  18.000000  25.000000   8.000000
# 6   S1393  남   2.000000  25.000000  13.461538
# 7   S1399  남  13.461538   2.000000  17.000000
# 8   S1411  여  19.000000  12.000000  17.000000
# 9   S1411  여  19.000000  12.000000  17.000000
# 10  S1414  여  18.000000  13.461538  23.000000
# 11  S1421  3   9.000000  12.000000   1.000000
# 12  S1424  여  19.000000   2.000000  15.000000
# 13  S1428  남  19.000000  13.461538   2.000000
# 14  S1433  남  19.000000  16.000000   5.000000

# %%
df4 = pd.read_excel('성적4.xlsx')
df4
# Out:
#        ID  성별    출석  프로젝트    실험
# 0   S1233   1   2.0  12.0  25.0
# 1   S1244   1  17.0   2.0  22.0
# 2   S1254   1   2.0  16.0  25.0
# 3   S1244   3   NaN  11.0  25.0
# 4   S1384   1  12.0  22.0  12.0
# 5   S1391   2  18.0  25.0   8.0
# 6   S1393   1   2.0  25.0   NaN
# 7   S1399   1   NaN   2.0  17.0
# 8   S1411   2  19.0  12.0  17.0
# 9   S1411   2  19.0  12.0  17.0
# 10  S1414   2  18.0   NaN  23.0
# 11  S1421   3   9.0  12.0   1.0
# 12  S1424   2  19.0   2.0  15.0
# 13  S1428   1  19.0   NaN   2.0
# 14  S1433   1  19.0  16.0   5.0

# %%
df4['성별'].value_counts()
# Out:
# 성별
# 1    8
# 2    5
# 3    2
# Name: count, dtype: int64

# %%
df4['성별'] = df4['성별'].replace(3,2)

# %%
df4['성별'].value_counts()
# Out:
# 성별
# 1    8
# 2    7
# Name: count, dtype: int64

# %%
df4.duplicated(['ID'])
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
df4
# Out:
#        ID  성별    출석  프로젝트    실험
# 0   S1233   1   2.0  12.0  25.0
# 1   S1244   1  17.0   2.0  22.0
# 2   S1254   1   2.0  16.0  25.0
# 3   S1244   2   NaN  11.0  25.0
# 4   S1384   1  12.0  22.0  12.0
# 5   S1391   2  18.0  25.0   8.0
# 6   S1393   1   2.0  25.0   NaN
# 7   S1399   1   NaN   2.0  17.0
# 8   S1411   2  19.0  12.0  17.0
# 9   S1411   2  19.0  12.0  17.0
# 10  S1414   2  18.0   NaN  23.0
# 11  S1421   2   9.0  12.0   1.0
# 12  S1424   2  19.0   2.0  15.0
# 13  S1428   1  19.0   NaN   2.0
# 14  S1433   1  19.0  16.0   5.0

# %%
df4.duplicated(['성별'])
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# dtype: bool

# %%
df4.drop_duplicates(['ID'])
# Out:
#        ID  성별    출석  프로젝트    실험
# 0   S1233   1   2.0  12.0  25.0
# 1   S1244   1  17.0   2.0  22.0
# 2   S1254   1   2.0  16.0  25.0
# 4   S1384   1  12.0  22.0  12.0
# 5   S1391   2  18.0  25.0   8.0
# 6   S1393   1   2.0  25.0   NaN
# 7   S1399   1   NaN   2.0  17.0
# 8   S1411   2  19.0  12.0  17.0
# 10  S1414   2  18.0   NaN  23.0
# 11  S1421   2   9.0  12.0   1.0
# 12  S1424   2  19.0   2.0  15.0
# 13  S1428   1  19.0   NaN   2.0
# 14  S1433   1  19.0  16.0   5.0

# %%
df4.drop_duplicates(subset=['ID','성별'],keep='last')
# Out:
#        ID  성별    출석  프로젝트    실험
# 0   S1233   1   2.0  12.0  25.0
# 1   S1244   1  17.0   2.0  22.0
# 2   S1254   1   2.0  16.0  25.0
# 3   S1244   2   NaN  11.0  25.0
# 4   S1384   1  12.0  22.0  12.0
# 5   S1391   2  18.0  25.0   8.0
# 6   S1393   1   2.0  25.0   NaN
# 7   S1399   1   NaN   2.0  17.0
# 9   S1411   2  19.0  12.0  17.0
# 10  S1414   2  18.0   NaN  23.0
# 11  S1421   2   9.0  12.0   1.0
# 12  S1424   2  19.0   2.0  15.0
# 13  S1428   1  19.0   NaN   2.0
# 14  S1433   1  19.0  16.0   5.0

# %%
df4.drop_duplicates(subset=['ID','성별'],keep=False)
# Out:
#        ID  성별    출석  프로젝트    실험
# 0   S1233   1   2.0  12.0  25.0
# 1   S1244   1  17.0   2.0  22.0
# 2   S1254   1   2.0  16.0  25.0
# 3   S1244   2   NaN  11.0  25.0
# 4   S1384   1  12.0  22.0  12.0
# 5   S1391   2  18.0  25.0   8.0
# 6   S1393   1   2.0  25.0   NaN
# 7   S1399   1   NaN   2.0  17.0
# 10  S1414   2  18.0   NaN  23.0
# 11  S1421   2   9.0  12.0   1.0
# 12  S1424   2  19.0   2.0  15.0
# 13  S1428   1  19.0   NaN   2.0
# 14  S1433   1  19.0  16.0   5.0

# %%
df = pd.read_csv('공공자전거 대여소 정보(23.06월 기준).csv',encoding='cp949',header=4)
df
# Out:
#       대여소번호            보관소(대여소)명  자치구                             상세주소  \
# 0       301          경복궁역 7번출구 앞  종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞
# 1       302          경복궁역 4번출구 뒤  종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤
# 2       303          광화문역 1번출구 앞  종로구       서울특별시 종로구 세종대로 지하189 세종로공원
# 3       305               종로구청 옆  종로구               서울특별시 종로구 세종로 84-1
# 4       307            서울역사박물관 앞  종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞
# ...     ...                  ...  ...                              ...
# 2744   3699              상일파출소 옆  강동구                    강동구 상일동 520-1
# 2745   3700      강변그대가리버뷰 입구 맞은편  강동구                    강동구 천호동 250-7
# 2746   3701                방아삼거리  강동구                    강동구 둔촌동 118-2
# 2747   4951   강동농협 버스정류소 앞(광채빌라)  강동구                   강동구 암사동 488-21
# 2748   4952         천호시장 버스정류소 옆  강동구                  강동구 천호동 397-465
#
#              위도          경도        설치시기  거치대수  거치 운영방식
# 0     37.575794  126.971451   2015.10.7  20.0  대수   QR
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2749 entries, 0 to 2748
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   대여소번호      2749 non-null   int64
#  1   보관소(대여소)명  2749 non-null   object
#  2   자치구        2749 non-null   object
#  3   상세주소       2749 non-null   object
#  4   위도         2749 non-null   float64
#  5   경도         2749 non-null   float64
#  6   설치시기       2749 non-null   object
#  7   거치대수       1315 non-null   float64
#  8   거치         1582 non-null   object
#  9   운영방식       2749 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 214.9+ KB

# %%
df.isna().sum()
# Out:
# 대여소번호           0
# 보관소(대여소)명       0
# 자치구             0
# 상세주소            0
# 위도              0
# 경도              0
# 설치시기            0
# 거치대수         1434
# 거치           1167
# 운영방식            0
# dtype: int64

# %%
df.dropna(subset=['거치대수'],axis=0,inplace=True)

# %%
df.isna().sum()
# Out:
# 대여소번호           0
# 보관소(대여소)명       0
# 자치구             0
# 상세주소            0
# 위도              0
# 경도              0
# 설치시기            0
# 거치대수            0
# 거치           1167
# 운영방식            0
# dtype: int64

# %%
df.fillna(method='ffill')
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_26347/253117906.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#       대여소번호           보관소(대여소)명  자치구                             상세주소  \
# 0       301         경복궁역 7번출구 앞  종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞
# 1       302         경복궁역 4번출구 뒤  종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤
# 2       303         광화문역 1번출구 앞  종로구       서울특별시 종로구 세종대로 지하189 세종로공원
# 3       305              종로구청 옆  종로구               서울특별시 종로구 세종로 84-1
# 4       307           서울역사박물관 앞  종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞
# ...     ...                 ...  ...                              ...
# 2678   1059     래미안 강동팰리스(102동)  강동구                   강동구 천호동 166-56
# 2679   1060            천일초교 사거리  강동구                   강동구 천호동 217-18
# 2680   1061   천호초교 입구 사거리(일주빌딩)  강동구                    강동구 천호동 234-2
# ...

# %%
df.fillna(method='bfill')
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_26347/4194935721.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#       대여소번호           보관소(대여소)명  자치구                             상세주소  \
# 0       301         경복궁역 7번출구 앞  종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞
# 1       302         경복궁역 4번출구 뒤  종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤
# 2       303         광화문역 1번출구 앞  종로구       서울특별시 종로구 세종대로 지하189 세종로공원
# 3       305              종로구청 옆  종로구               서울특별시 종로구 세종로 84-1
# 4       307           서울역사박물관 앞  종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞
# ...     ...                 ...  ...                              ...
# 2678   1059     래미안 강동팰리스(102동)  강동구                   강동구 천호동 166-56
# 2679   1060            천일초교 사거리  강동구                   강동구 천호동 217-18
# 2680   1061   천호초교 입구 사거리(일주빌딩)  강동구                    강동구 천호동 234-2
# ...

# %%
df.interpolate()
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_26347/3087911016.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#       대여소번호           보관소(대여소)명  자치구                             상세주소  \
# 0       301         경복궁역 7번출구 앞  종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞
# 1       302         경복궁역 4번출구 뒤  종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤
# 2       303         광화문역 1번출구 앞  종로구       서울특별시 종로구 세종대로 지하189 세종로공원
# 3       305              종로구청 옆  종로구               서울특별시 종로구 세종로 84-1
# 4       307           서울역사박물관 앞  종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞
# ...     ...                 ...  ...                              ...
# 2678   1059     래미안 강동팰리스(102동)  강동구                   강동구 천호동 166-56
# 2679   1060            천일초교 사거리  강동구                   강동구 천호동 217-18
# 2680   1061   천호초교 입구 사거리(일주빌딩)  강동구                    강동구 천호동 234-2
# ...

# %%
df['자치구'].value_counts().sort_index()
# Out:
# 자치구
# 강남구     93
# 강동구     54
# 강북구     35
# 강서구     71
# 관악구     44
# 광진구     48
# 구로구     64
# 금천구     40
# 노원구     57
# 도봉구     33
# 동대문구    47
# 동작구     41
# 마포구     43
# 서대문구    37
# 서초구     78
# 성동구     56
# 성북구     50
# 송파구     85
# 양천구     52
# 영등포구    57
# 용산구     38
# 은평구     57
# 종로구     58
# 중구      32
# 중랑구     45
# Name: count, dtype: int64

# %%
df.duplicated(['자치구'])
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2678     True
# 2679     True
# 2680     True
# 2681     True
# 2682     True
# Length: 1315, dtype: bool

# %%
df.drop_duplicates(['자치구'])
# Out:
#       대여소번호             보관소(대여소)명   자치구                              상세주소  \
# 0       301           경복궁역 7번출구 앞   종로구   서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞
# 103     300                 정동사거리    중구            서울특별시 중구 정동길 2-1 정동사거리
# 191     800                목월공원 앞   용산구     서울특별시 용산구 원효로4가 109-10 목월공원 앞
# 282    3511              응봉역 1번출구   성동구       서울특별시 성동구 고산자로 123 응봉동 3-10
# 374    3500               군자역2번출구   광진구         서울특별시 광진구 능동로 313 군자역2번출구
# 460     600             휘경2동 주민센터  동대문구      서울특별시 동대문구 한천로 329 휘경2동 주민센터
# 544    1401              극동늘푸른아파트   중랑구    서울특별시 중랑구 동일로 941 중랑구 묵동 189-2
# 637    1302          한성대입구역6번출구 뒤   성북구     서울특별시 성북구 동소문로 1 한성대입구역6번출구 뒤
# 719    1501       미아역 3번,4번 출구 사이   강북구  서울특별시 강북구 도봉로 196 미아역 3,4번 출구 사이
# 780    1702            녹천역 1번출구 앞   도봉구                서울특별시 도봉구 창동 426-6
# 857    1602                광운대역 앞   노원구  서울특별시 노원구 석계로 98-2 노원구 월계동 412-1
# 992     900                은평예술회관   은평구         서울특별시 은평구 녹번동 85-4 은평예술회관
# ...
